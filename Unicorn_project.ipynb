# %% [markdown]
# # Unicorn project

# %% [markdown]
# ## Preparations

# %% [markdown]
# ### Installing and importing packages

# %%
import pandas as pd
import sqlalchemy as sa
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# ### Making a connection

# %% [markdown]
# Step 1:

# %%
unicorn_url = 'postgresql://Test:bQNxVzJL4g6u@ep-noisy-flower-846766-pooler.us-east-2.aws.neon.tech/Unicorn?sslmode=require'

# %% [markdown]
# Step 2:

# %%
engine = sa.create_engine(unicorn_url)
connection = engine.connect().execution_options(isolation_level="AUTOCOMMIT")

# %% [markdown]
# ## Queries

# %% [markdown]
# 1. How many customers do we have in the data?

# %%
query= """
SELECT COUNT(DISTINCT customer_name)
FROM customers;
"""

display(pd.read_sql(sa.text(query),connection))
# Out:
#    count
# 0    795

# %% [markdown]
# 2. What was the city with the most profit for the company in 2015?

# %%
query= """
SELECT o.shipping_city, SUM(od.order_profits) AS total_profit
FROM orders o
JOIN order_details od ON o.order_id = od.order_id
WHERE EXTRACT(YEAR FROM o.order_date) = 2015
GROUP BY o.shipping_city
ORDER BY total_profit DESC
LIMIT 1;
"""

display(pd.read_sql(sa.text(query),connection))
# Out:
#    shipping_city  total_profit
# 0  New York City       14753.0

# %% [markdown]
# 3. In 2015, what was the most profitable city's profit?

# %%
query= """
WITH MonthlyData AS (
    SELECT
        EXTRACT(MONTH FROM o.order_date) AS month_number,
        SUM(od.order_profits)
    FROM orders o
  	JOIN order_details od ON o.order_id = od.order_id
    WHERE EXTRACT(YEAR FROM o.order_date) = 2015 AND o.shipping_city = 'New York City'
    GROUP BY EXTRACT(MONTH FROM o.order_date)
)
SELECT sum AS profit_by_month,
       TO_CHAR(TO_TIMESTAMP(month_number::TEXT, 'MM'), 'Month') AS month_name
FROM MonthlyData
ORDER BY profit_by_month DESC;
"""

display(pd.read_sql(sa.text(query),connection))
# Out:
#     profit_by_month month_name
# 0            8675.0  September
# 1            2900.0  November
# 2            2736.0  December
# 3             335.0  May
# 4             308.0  July
# 5             303.0  June
# 6             234.0  August
# 7              49.0  October
# 8              27.0  April
# 9              10.0  February
# 10              1.0  January
# 11           -825.0  March

# %% [markdown]
# 4. How many different cities do we have in the data?

# %%
query= """
SELECT COUNT(DISTINCT shipping_city) AS total_cities
FROM orders
"""

display(pd.read_sql(sa.text(query),connection))
# Out:
#    total_cities
# 0           531

# %% [markdown]
# 5. Show the total spent by customers from low to high.

# %%
query= """
SELECT o.customer_id, c.customer_name, SUM(od.order_sales) AS total_spent_by_customer
FROM customers c
JOIN orders o ON c.customer_id = o.customer_id
JOIN order_details od ON od.order_id = o.order_id
GROUP BY c.customer_name, o.customer_id
ORDER BY SUM(od.order_sales)
"""

display(pd.read_sql(sa.text(query),connection))
# Out:
#      customer_id           customer_name  total_spent_by_customer
# 0            738           Thais Sissman                      5.0
# 1            456            Lela Donovan                      5.0
# 2            546         Mitch Gastineau                     16.0
# 3            124            Carl Jackson                     17.0
# 4            657              Roy Skaria                     22.0
# 5            626         Ricardo Emerson                     48.0
# 6            725          Susan Gilcrest                     49.0
# 7            448            Larry Blacks                     50.0
# 8              9            Adrian Shami                     58.0
# 9            355         Jasper Cacioppo                     72.0
# 10           292          Fred Wasserman                     81.0
# 11            38          Anemone Ratner                     88.0
# 12           419              Karen Seio                     89.0
# 13           649           Roland Murray                     98.0
# 14           169           Clay Cheatham                    113.0
# 15           248               Ed Ludwig                    125.0
# 16            95           Bobby Odegard                    131.0
# 17           613          Phillip Breyer                    133.0
# 18           310             Greg Hansen                    147.0
# 19           529          Michael Oakman                    154.0
# 20           229           Dianna Arnett                    157.0
# 21           605           Pete Takahito                    160.0
# 22            54       Anthony O'Donnell                    161.0
# 23           550            Muhammed Lee                    162.0
# 24            51       Anthony Garverick                    170.0
# 25           383            Joel Jenkins                    195.0
# 26            26          Allen Goldenen                    201.0
# 27           333           Hilary Holden                    219.0
# 28           642          Robert Barroso                    221.0
# 29           316            Guy Thornton                    227.0
# 30           270               Erin Mull                    228.0
# 31           315             Guy Phonely                    237.0
# 32           594              Paul Lucas                    239.0
# 33           666          Sally Matthias                    243.0
# 34           318           Harold Dahlen                    251.0
# 35            34          Andrew Roberts                    264.0
# 36            98            Brad Norvell                    266.0
# 37           237       Dorothy Dickinson                    269.0
# 38           571          Nicole Brennan                    274.0
# 39            72               Bart Folk                    274.0
# 40           719          Stuart Calhoun                    278.0
# 41           722              Sung Chung                    281.0
# 42           162             Chuck Magee                    287.0
# 43           449            Larry Hughes                    288.0
# 44           371           Jill Matthias                    305.0
# 45           361       Jennifer Halladay                    310.0
# 46           467             Lisa Hazard                    318.0
# 47           104          Brendan Dodson                    321.0
# 48           450              Larry Tron                    330.0
# 49           235               Don Weiss                    343.0
# 50           324             Heather Jas                    359.0
# 51           279           Evan Minnotte                    367.0
# 52            20     Aleksandra Gannaway                    367.0
# 53           481        Lycoris Saunders                    368.0
# 54           521           Melanie Seite                    370.0
# 55           564        Neil Französisch                    377.0
# 56           787           Vivian Mathis                    381.0
# 57           354       Jason Klamczynski                    384.0
# 58            71           Barry Weirich                    386.0
# 59           400             Joy Daniels                    386.0
# 60           495           Mark Haberlin                    400.0
# 61            99             Brad Thomas                    415.0
# 62           705            Sonia Sunley                    418.0
# 63           785             Vivek Grady                    427.0
# 64           701                Shui Tom                    432.0
# 65           750             Tim Taslimi                    439.0
# 66           437          Kelly Williams                    449.0
# 67           443            Khloe Miller                    454.0
# 68           269          Erin Creighton                    462.0
# 69           395         Joni Sundaresam                    471.0
# 70           174             Corey Roper                    475.0
# 71           501          MaryBeth Skach                    476.0
# 72           700         Shirley Schmidt                    478.0
# 73            37              Andy Yotov                    496.0
# 74           637             Rob Beeghly                    528.0
# 75           387             John Huston                    529.0
# 76           123         Cari Schnelling                    538.0
# 77           163             Chuck Sachs                    551.0
# 78           128           Carlos Meador                    565.0
# 79           565            Neil Knudson                    571.0
# 80           109              Brian Derr                    583.0
# 81           221       Denise Leinenbach                    585.0
# 82            16            Alan Shonely                    586.0
# 83           488           Maria Zettner                    594.0
# 84            65          Barbara Fisher                    600.0
# 85            96           Bobby Trafton                    605.0
# 86           620            Ralph Ritter                    615.0
# 87            64            Astrea Jones                    629.0
# 88           502            Mathew Reese                    640.0
# 89           131            Carol Darley                    641.0
# 90           477              Lori Olson                    644.0
# 91           399               Joy Bell-                    644.0
# 92            56            Anthony Witt                    649.0
# 93            44              Anna Chung                    658.0
# 94           118             Bryan Davis                    658.0
# 95            84          Berenike Kampe                    659.0
# 96            22            Alex Grayson                    662.0
# 97           754             Toby Ritter                    676.0
# 98           262           Eric Hoffmann                    684.0
# 99           606            Peter Bühler                    689.0
# 100          403            Julia Dunbar                    696.0
# 101          362        Jennifer Jackson                    710.0
# 102          603          Pete Armstrong                    730.0
# 103          585       Patricia Hirasaki                    730.0
# 104           39             Angele Hood                    738.0
# 105          331       Henry MacAllister                    738.0
# 106          636         Ritsa Hightower                    740.0
# 107          586         Patrick Bzostek                    741.0
# 108          535       Michelle Lonsdale                    742.0
# 109          767           Tracy Collins                    742.0
# 110          338             Ivan Gibson                    744.0
# 111           66         Barry Blumstein                    744.0
# 112          239            Dorris liebe                    756.0
# 113          471           Liz Pelletier                    757.0
# 114          716             Steven Ward                    759.0
# 115          670         Sandra Flanagan                    764.0
# 116          551      Muhammed MacIntyre                    774.0
# 117          525        Michael Granlund                    777.0
# 118          322            Harry Greene                    785.0
# 119           85           Beth Fritzler                    791.0
# 120          508          Matthew Clasen                    795.0
# 121          209          David Kendrick                    798.0
# 122          105           Brendan Murry                    809.0
# 123           24          Alice McCarthy                    813.0
# 124          745          Thomas Brumley                    816.0
# 125          265           Erica Hackney                    827.0
# 126          756              Todd Boyes                    834.0
# 127           42              Ann Steele                    835.0
# 128          144         Charles Sheldon                    844.0
# 129          784          Vivek Gonzalez                    846.0
# 130          779          Vicky Freymann                    847.0
# 131          531         Michael Stewart                    855.0
# 132          406         Julie Creighton                    858.0
# 133           59              Art Foster                    862.0
# 134          379          Jocasta Rupert                    864.0
# 135          376             Jim Mitchum                    865.0
# 136          629        Richard Eichhorn                    878.0
# 137          319            Harold Engle                    884.0
# 138          665           Sally Knutson                    884.0
# 139          141            Chad Sievert                    885.0
# 140          663              Ryan Crowe                    886.0
# 141            1           Aaron Bergman                    887.0
# 142          329             Henia Zydlo                    887.0
# 143          394          Joni Blumstein                    901.0
# 144          704            Sonia Cooley                    902.0
# 145          135     Catherine Glotzbach                    906.0
# 146          426        Katrina Bavinger                    909.0
# 147           17    Alejandro Ballentine                    914.0
# 148          499           Mary O'Rourke                    922.0
# 149          278              Evan Henry                    925.0
# 150           28           Alyssa Crouse                    926.0
# 151          263            Eric Murdock                    934.0
# 152          510        Maureen Fritzler                    936.0
# 153          261            Eric Barreto                    944.0
# 154          655         Roy Französisch                    947.0
# 155          120           Bryan Spruell                    950.0
# 156          617            Rachel Payne                    955.0
# 157          352          Jason Fortune-                    955.0
# 158          393         Jonathan Howell                    959.0
# 159          724           Sung Shariari                    966.0
# 160          654             Roy Collins                    968.0
# 161           10             Aimee Bixby                    969.0
# 162          661       Russell D'Ascenzo                    971.0
# 163          755           Toby Swindell                    974.0
# 164           70              Barry Pond                    983.0
# 165          439             Ken Brennan                    984.0
# 166          780            Victor Preis                    994.0
# 167          116              Bruce Geld                   1006.0
# 168          482              Lynn Smith                   1007.0
# 169          621           Randy Bradley                   1008.0
# 170          479            Luke Schmidt                   1009.0
# 171          689              Sean Wendt                   1019.0
# 172          748           Tiffany House                   1024.0
# 173          543            Mike Kennedy                   1031.0
# 174          742           Theresa Coyne                   1038.0
# 175          272          Eudokia Martin                   1041.0
# 176          244           Duane Huffman                   1042.0
# 628          284            Frank Hawley                   4257.0
# 629           15       Alan Schoenberger                   4262.0
# 630          752           Toby Carlisle                   4266.0
# 631          631             Rick Duston                   4272.0
# 632          192             Dana Kaydos                   4283.0
# 633          723                Sung Pak                   4283.0
# 634          503            Matt Abelman                   4300.0
# 635          557       Natalie DeCherney                   4329.0
# 636          715           Steven Roelle                   4345.0
# 637          297           Gary Zandusky                   4355.0
# 638          255           Ellis Ballard                   4358.0
# 639          681              Scot Coram                   4374.0
# 640           57          Arianne Irving                   4376.0
# 641          100         Bradley Drucker                   4410.0
# 642          428         Katrina Willman                   4418.0
# 643          346            Jamie Kunitz                   4427.0
# 644          494            Mark Cousins                   4433.0
# 645          741        Theone Pippenger                   4456.0
# 646          461          Linda Cazamias                   4492.0
# 647          717      Stewart Carmichael                   4494.0
# 648           53         Anthony Johnson                   4501.0
# 649           60           Arthur Gainer                   4511.0
# 650           55          Anthony Rawles                   4523.0
# 651          203             Dave Brooks                   4532.0
# 652          275            Eugene Moren                   4589.0
# 653          669        Sample Company A                   4626.0
# 654          431           Kean Thornton                   4642.0
# 655          217       Deborah Brumfield                   4655.0
# 656          271              Erin Smith                   4657.0
# 657          452          Laurel Beltran                   4705.0
# 658          630            Rick Bensley                   4714.0
# 659          304       Giulietta Baptist                   4717.0
# 660          766         Tracy Blumstein                   4737.0
# 661           74            Bart Watters                   4752.0
# 662          375                Jim Kriz                   4762.0
# 663          721            Sue Ann Reed                   4767.0
# 664          660       Russell Applegate                   4794.0
# 665          214               Dean Katz                   4802.0
# 666           14              Alan Hwang                   4805.0
# 667           52          Anthony Jacobs                   4868.0
# 668          381           Joe Kamberova                   4868.0
# 669          325        Heather Kirkland                   4877.0
# 670          611       Philisse Overcash                   4893.0
# 671          447            Kunst Miller                   4910.0
# 672          737             Ted Trevino                   4916.0
# 673          337            Irene Maddox                   4931.0
# 674          204           Dave Hallsten                   4933.0
# 675          436           Kelly Lampkin                   5019.0
# 676          339             Ivan Liston                   5040.0
# 677           43           Anna Andreadi                   5087.0
# 678          544          Mike Pelletier                   5090.0
# 679          460            Lena Radford                   5143.0
# 680          625            Resi Pölking                   5155.0
# 681          652              Ross Baird                   5224.0
# 682          714       Steven Cartwright                   5226.0
# 683          321             Harold Ryan                   5251.0
# 684          548        Mitch Willingham                   5254.0
# 685          231           Dianna Wilson                   5272.0
# 686          734       Tamara Willingham                   5278.0
# 687          760            Tom Prescott                   5329.0
# 688          547            Mitch Webber                   5342.0
# 689          762           Tonja Turnell                   5365.0
# 690          746             Thomas Seio                   5370.0
# 691           62         Arthur Wiediger                   5385.0
# 692          138          Cathy Prescott                   5401.0
# 693          480              Luke Weiss                   5422.0
# 694          707        Stefania Perrino                   5443.0
# 695          791          Yoseph Carroll                   5455.0
# 696          260              Emily Phan                   5481.0
# 697          225           Dennis Pardue                   5482.0
# 698          540          Mick Hernandez                   5503.0
# 699           30                 Amy Cox                   5529.0
# 700          554            Naresj Patel                   5532.0
# 701          729          Suzanne McNair                   5563.0
# 702           21              Alex Avila                   5565.0
# 779          313               Greg Tran                  11821.0
# 780          757            Todd Sumrall                  11891.0
# 781          157      Christopher Conant                  12128.0
# 782          673            Sanjit Engle                  12209.0
# 783          335            Hunter Lopez                  12875.0
# 784           91            Bill Shonely                  13513.0
# 785          672            Sanjit Chand                  14145.0
# 786          442            Ken Lonsdale                  14175.0
# 787            7           Adrian Barton                  14476.0
# 788          758            Tom Ashbrook                  14596.0
# 789          623            Raymond Buch                  15117.0
# 790          388                John Lee                  16744.0
# 791          731            Tamara Chand                  19050.0
# 792          687             Sean Miller                  25042.0

# %% [markdown]
# 6. What is the most profitable city in the State of Tennessee?

# %%
query= """
SELECT o.shipping_city, SUM(od.order_profits) AS total_profit
FROM order_details od
JOIN orders o ON od.order_id = o.order_id
WHERE o.shipping_state = 'Tennessee'
GROUP BY o.shipping_city
ORDER BY SUM(od.order_profits) DESC
LIMIT 1;
"""

display(pd.read_sql(sa.text(query),connection))
# Out:
#   shipping_city  total_profit
# 0       Lebanon          83.0

# %% [markdown]
# 7. What’s the average annual profit for that city across all years?

# %%
query= """
SELECT AVG(order_profits) AS avg_profit
FROM orders
JOIN order_details ON orders.order_id = order_details.order_id
WHERE shipping_city = 'Lebanon'
"""

display(pd.read_sql(sa.text(query),connection))
# Out:
#    avg_profit
# 0   27.666667

# %% [markdown]
# 8. What is the distribution of customer types in the data?

# %%
query= """
SELECT customer_segment,
       COUNT(DISTINCT customer_id)
FROM customers
GROUP BY customer_segment;
"""

display(pd.read_sql(sa.text(query),connection))
# Out:
#   customer_segment  count
# 0         Consumer    410
# 1        Corporate    237
# 2      Home Office    148

# %% [markdown]
# 9. What’s the most profitable product category on average in Iowa across all years?

# %%
query= """
WITH category_profits AS (
  SELECT
    p.product_category,
    SUM(od.order_profits) AS total_profit,
    COUNT(DISTINCT o.order_id) AS order_count,
    AVG(od.order_profits) AS avg_profit_per_order
  FROM orders o
  JOIN order_details od ON o.order_id = od.order_id
  JOIN product p ON od.product_id = p.product_id
  WHERE o.shipping_state = 'Iowa'
  GROUP BY p.product_category
)
SELECT product_category, avg_profit_per_order
FROM category_profits
ORDER BY avg_profit_per_order DESC
LIMIT 1;
"""

display(pd.read_sql(sa.text(query),connection))
# Out:
#   product_category  avg_profit_per_order
# 0        Furniture                130.25

# %% [markdown]
# 10. What is the most popular product in that category across all states in 2016?

# %%
query= """
SELECT p.product_name, SUM(od.quantity) AS total_sold
FROM orders o
JOIN order_details od ON o.order_id = od.order_id
JOIN product p ON od.product_id = p.product_id
WHERE p.product_category = 'Furniture'
  AND EXTRACT(YEAR FROM order_date) = 2016
GROUP BY p.product_name
ORDER BY total_sold DESC
LIMIT 5;
"""

display(pd.read_sql(sa.text(query),connection))
# Out:
#                                  product_name  total_sold
# 0  Global Push Button Manager's Chair, Indigo        22.0
# 1   Global High-Back Leather Tilter, Burgundy        20.0
# 2                     DAX Wood Document Frame        19.0
# 3                        KI Conference Tables        19.0
# 4             Bevis 36 x 72 Conference Tables        18.0

# %% [markdown]
# 11. Which customer got the most discount in the data? (in total amount)

# %%
query= """
WITH discount_data AS (
      SELECT orders.order_id as order_id,
             customers.customer_id as customer_id,
             customers.customer_name as customer_name,
             order_details.order_sales as order_sales,
             order_details.order_discount as discount_in_percentages,
             (order_details.order_sales/(1-order_details.order_discount)) AS original_price
      FROM customers
      JOIN orders ON customers.customer_id = orders.customer_id
      JOIN order_details ON orders.order_id = order_details.order_id
)
SELECT customer_id,
       original_price - order_sales AS total_discount_amount
FROM discount_data
ORDER BY total_discount_amount DESC
LIMIT 10;
"""

display(pd.read_sql(sa.text(query),connection))
# Out:
#    customer_id  total_discount_amount
# 0          687                22638.0
# 1          166                10500.0
# 2          478                 8712.0
# 3          308                 8000.0
# 4          330                 7560.0
# 5          560                 6100.0
# 6          694                 5950.0
# 7          157                 5600.0
# 8           76                 5440.0
# 9          792                 4356.0

# %% [markdown]
# 12. How widely did monthly profits vary in 2018?

# %%
query= """
WITH monthly_profits AS (
  SELECT
    DATE_TRUNC('month', order_date) AS order_month,
    SUM(order_profits) AS total_profit
  FROM orders
  JOIN order_details ON orders.order_id = order_details.order_id
  WHERE EXTRACT(YEAR FROM order_date) = 2018
  GROUP BY DATE_TRUNC('month', order_date)
)
SELECT
  order_month,
  total_profit,
  COALESCE(total_profit - LAG(total_profit) OVER (ORDER BY order_month), 0) AS profit_change
FROM monthly_profits;
"""

display(pd.read_sql(sa.text(query),connection))
# Out:
#    order_month  total_profit  profit_change
# 0   2018-01-01        7137.0            0.0
# 1   2018-02-01        1612.0        -5525.0
# 2   2018-03-01       14758.0        13146.0
# 3   2018-04-01         934.0       -13824.0
# 4   2018-05-01        6342.0         5408.0
# 5   2018-06-01        8226.0         1884.0
# 6   2018-07-01        6951.0        -1275.0
# 7   2018-08-01        9034.0         2083.0
# 8   2018-09-01       10987.0         1953.0
# 9   2018-10-01        9272.0        -1715.0
# 10  2018-11-01        9217.0          -55.0
# 11  2018-12-01        8473.0         -744.0

# %% [markdown]
# 13. Which was the biggest order regarding sales in 2015?

# %%
query= """
SELECT o.order_id, SUM(od.order_sales) AS total_sales
FROM orders o
JOIN order_details od ON o.order_id = od.order_id
WHERE EXTRACT(YEAR FROM order_date) = 2015
GROUP BY o.order_id
ORDER BY total_sales DESC
LIMIT 1;

"""

display(pd.read_sql(sa.text(query),connection))
# Out:
#          order_id  total_sales
# 0  CA-2015-145317      23660.0

# %% [markdown]
# 14. What was the rank of each city in the East region in 2015 in quantity?

# %%
query= """
WITH ranked_cities AS (
  SELECT
    shipping_city,
    SUM(od.quantity) AS total_quantity,
    RANK() OVER (ORDER BY SUM(od.quantity) DESC) AS city_rank
  FROM orders o
  JOIN order_details od ON o.order_id = od.order_id
  WHERE EXTRACT(YEAR FROM order_date) = 2015
  AND shipping_region = 'East'
  GROUP BY shipping_city
)
SELECT city_rank, shipping_city, total_quantity
FROM ranked_cities
ORDER BY city_rank;
"""

display(pd.read_sql(sa.text(query),connection))
# Out:
#     city_rank  shipping_city  total_quantity
# 0           1  New York City          1708.0
# 1           2   Philadelphia           403.0
# 2           3       Columbus           167.0
# 3           4         Newark            64.0
# 4           5      Fairfield            53.0
# 5           6     Long Beach            44.0
# 6           7       Lakewood            38.0
# 7           8      Lancaster            36.0
# 8           9       Lawrence            31.0
# 9          10          Dover            30.0
# 10         11     Hackensack            28.0
# 11         12         Bangor            24.0
# 12         12          Utica            24.0
# 13         14         Lowell            23.0
# 14         15        Yonkers            22.0
# 15         16     Wilmington            21.0
# 16         17        Clinton            20.0
# 17         17      Baltimore            20.0
# 18         17       Cranston            20.0
# 19         20        Everett            19.0
# 20         20     Providence            19.0
# 21         20        Buffalo            19.0
# 22         23         Medina            16.0
# 23         24        Meriden            15.0
# 24         24        Beverly            15.0
# 25         26   New Rochelle            14.0
# 26         26        Bristol            14.0
# 27         28      Hempstead            12.0
# 28         28      Cleveland            12.0
# 29         28      Rochester            12.0
# 30         28         Toledo            12.0
# 31         28      Watertown            12.0
# 32         33        Chester            11.0
# 33         33           Troy            11.0
# 34         33       Franklin            11.0
# 35         36          Akron            10.0
# 36         37        Clifton             9.0
# 37         37      Jamestown             9.0
# 38         37        Concord             9.0
# 39         40       Columbia             8.0
# 40         40         Lorain             8.0
# 41         40       Hamilton             8.0
# 42         40     Cincinnati             8.0
# 43         44          Mason             7.0
# 44         44   Mount Vernon             7.0
# 45         44         Linden             7.0
# 46         47        Reading             6.0
# 47         47         Revere             6.0
# 48         49           Kent             5.0
# 49         49      Oceanside             5.0
# 50         49    Springfield             5.0
# 51         52         Orange             4.0
# 52         52          Parma             4.0
# 53         54  Niagara Falls             3.0
# 54         54     Plainfield             3.0
# 55         54         Marion             3.0
# 56         57  Bowling Green             2.0
# 57         57       Freeport             2.0
# 58         57     Middletown             2.0
# 59         57     Woonsocket             2.0

# %% [markdown]
# 15. Display customer names for customers who are in the segment ‘Consumer’ or ‘Corporate.’ How many customers are there in total?

# %%
query= """
SELECT
    COUNT(CASE WHEN customer_segment = 'Consumer' THEN 1 END) AS count_consumer,
    COUNT(CASE WHEN customer_segment = 'Corporate' THEN 1 END) AS count_corporate,
    COUNT(CASE WHEN customer_segment IN ('Consumer', 'Corporate') THEN 1 END) AS count_both
FROM
    customers;
"""

display(pd.read_sql(sa.text(query),connection))
# Out:
#    count_consumer  count_corporate  count_both
# 0             410              237         647

# %% [markdown]
# 16. Calculate the difference between the largest and smallest order quantities for product id ‘100.’

# %%
query= """
SELECT MAX(od.quantity) - MIN(od.quantity) AS quantity_difference
FROM orders o
JOIN order_details od ON o.order_id = od.order_id
WHERE od.product_id = 100;
"""

display(pd.read_sql(sa.text(query),connection))
# Out:
#    quantity_difference
# 0                    4

# %% [markdown]
# 17. Calculate the percent of products that are within the category ‘Furniture.’

# %%
query= """
WITH total_products AS (
  SELECT COUNT(*) AS total_count
  FROM product
),
furniture_count AS (
  SELECT COUNT(*) AS furniture_count
  FROM product
  WHERE product_category = 'Furniture'
)
SELECT furniture_count.furniture_count, total_products.total_count,
			ROUND(CAST(furniture_count.furniture_count AS NUMERIC) / CAST(total_products.total_count AS NUMERIC) * 100.0, 2) as furniture_percent
FROM furniture_count, total_products;

"""

display(pd.read_sql(sa.text(query),connection))
# Out:
#    furniture_count  total_count  furniture_percent
# 0              380         1850              20.54

# %% [markdown]
# 18. Display the number of product manufacturers with more than 1 product in the product table.

# %%
query= """
SELECT product_manufacturer,
			 COUNT(product_id) as count_of_products
FROM product
GROUP BY product_manufacturer
HAVING COUNT(*) > 1;
"""

display(pd.read_sql(sa.text(query),connection))
# Out:
#       product_manufacturer  count_of_products
# 0                   Linden                  2
# 1                  Iceberg                  3
# 2                  SanDisk                  8
# 3                  Memorex                 13
# 4                  Bulldog                  2
# 5                   Nortel                  4
# 6                  Quartet                  2
# 7                    Tyvek                  4
# 8                    Epson                  3
# 9                 XtraLife                  2
# 10                   Mitel                  2
# 11             Grandstream                  2
# 12               Panasonic                 18
# 13               Microsoft                  5
# 14               Wirebound                 11
# 15                     HTC                  2
# 16          Binney & Smith                  5
# 17                   Avaya                  4
# 18               Sterilite                  2
# 19              Tripp Lite                  3
# 20                REDIFORM                  5
# 21                     RCA                  5
# 22   Executive Impressions                 12
# 23                   Other                356
# 24                   Ultra                  4
# 25                   Bevis                 11
# 26                Atlantic                  4
# 27                   Sharp                  2
# 28                Verbatim                  5
# 29                  Hoover                 10
# 30                      GE                  7
# 31                   Sanyo                  2
# 32                   Lesro                  2
# 33                Barricks                  2
# 34                   Anker                  6
# 35                Advantus                 13
# 36                   Avery                 98
# 37                    Iris                  2
# 38                 Nu-Dell                  5
# 39                      HP                  4
# 40                   Eldon                 48
# 41                   Razer                  3
# 42                 Sanford                 11
# 43                    Balt                  3
# 44                    AT&T                 11
# 45                    Sony                  7
# 46               Universal                  5
# 47            Message Book                  3
# 48                 Stanley                  2
# 49                ClearOne                  2
# 50             Seth Thomas                  6
# 51                    Rush                  2
# 52                    Acco                 34
# 53              3D Systems                  2
# 54       Micro Innovations                  2
# 55                  Avanti                  2
# 56             Clearsounds                  2
# 57                  Holmes                  8
# 58                  C-Line                  4
# 59                   Xerox                173
# 60              Kensington                 11
# 61                  Eureka                  8
# 62                Standard                  2
# 63          WD My Passport                  3
# 64                   Prang                  3
# 65             Office Star                 12
# 66                 Harmony                  2
# 67                   Dixon                  9
# 68                 Okidata                  6
# 69                   Canon                 10
# 70                Alliance                  4
# 71                Electrix                  5
# 72               Deflect-o                  8
# 73                    Bush                 13
# 74           Howard Miller                 12
# 75                   Nokia                  3
# 76                Bionaire                  2
# 77                 Tennsco                 11
# 78                   Smead                  3
# 79                  Carina                  4
# 80                 Angle-D                  2
# 81                    Poly                  2
# 82                 Samsung                 11
# 83                     BIC                  5
# 84                  Maxell                 12
# 85                    TOPS                  7
# 86                 Imation                 11
# 87                    Hunt                  4
# 88                      LG                  3
# 89         Hewlett-Packard                 11
# 90                Euro Pro                  2
# 91                    Akro                  2
# 92                 Griffin                  2
# 93                     DAX                 17
# 94       Texas Instruments                  2
# 95                  Tensor                  4
# 96                  iOttie                  2
# 97                Kingston                  4
# 98                  Newell                 52
# 99              Chromcraft                  6
# 100                  Ibico                 12
# 101                    GBC                 45
# 102                Crayola                  2
# 103              Honeywell                  5
# 104                    DXL                  2
# 105                   Dana                  3
# 106                  Zebra                  4
# 107                NETGEAR                  3
# 108                  Adams                  9
# 109           Westinghouse                  3
# 110                    Hon                 33
# 111             First Data                  2
# 112                  SAFCO                 20
# 113            Martin-Yale                  2
# 114                  Cisco                 17
# 115               Motorola                  6
# 116                  Ativa                  3
# 117                Premier                  2
# 118               Logitech                 36
# 119           Wilson Jones                 23
# 120                     3M                  6
# 121                Polycom                  7
# 122                 Rogers                  4
# 123        Space Solutions                  3
# 124               Fellowes                 35
# 125              Riverside                  3
# 126                 Global                 40
# 127                  Array                  2
# 128                   Acme                 19
# 129                 Boston                 18
# 130                  Jabra                  4
# 131                Enermax                  3
# 132               Decoflex                  2
# 133                 Cubify                  2
# 134             O'Sullivan                 13
# 135              Stockwell                  2
# 136                   Luxo                  5
# 137                 Sauder                 11
# 138                 Storex                  3
# 139         Gould Plastics                  2
# 140            Peel & Seel                  2
# 141                    DMI                  2
# 142              KeyTronic                  4
# 143     Office Impressions                  2
# 144                  G. E.                  2
# 145          Master Caster                  4
# 146                  Ampad                  5
# 147               ACCOHIDE                  3
# 148               Bretford                  4
# 149                   Pyle                  2
# 150                 Belkin                 25
# 151           Things To Do                  2
# 152                 Square                  2
# 153              Hammermil                  2
# 154                    OIC                  5
# 155            Plantronics                 15
# 156                Jawbone                  2
# 157                  Apple                  4
# 158             Southworth                  8
# 159                  Tenex                 16
# 160                Lexmark                  4
# 161                Novimex                  4
# 162                     KI                  2
# 163               Cardinal                  8
# 164                Brother                  2
# 165             Strathmore                  3
# 166                Fiskars                  4
# 167               OtterBox                  4
# 168             Pressboard                  4

# %% [markdown]
# 19. Show the product_subcategory and the total number of products in the subcategory.

# %%
query= """
SELECT product_subcategory, COUNT(product_id) AS total_products
FROM product
GROUP BY product_subcategory
ORDER BY COUNT(product_id) DESC, product_subcategory;
"""

display(pd.read_sql(sa.text(query),connection))
# Out:
#    product_subcategory  total_products
# 0                Paper             277
# 1              Binders             211
# 2               Phones             189
# 3          Furnishings             186
# 4                  Art             157
# 5          Accessories             147
# 6              Storage             132
# 7           Appliances              97
# 8               Chairs              88
# 9               Labels              70
# 10            Machines              63
# 11              Tables              56
# 12           Bookcases              50
# 13           Envelopes              44
# 14            Supplies              36
# 15           Fasteners              34
# 16             Copiers              13

# %% [markdown]
# 20. Show the order from most to least products and then by product_subcategory name ascending.

# %%
query= """
SELECT o.order_id,
       p.product_id,
       p.product_subcategory,
       SUM(od.quantity) AS total_quantity
FROM orders o
JOIN order_details od ON o.order_id = od.order_id
JOIN product p ON od.product_id = p.product_id
GROUP BY o.order_id, p.product_id, p.product_subcategory
ORDER BY SUM(od.quantity) DESC, p.product_subcategory;
"""

display(pd.read_sql(sa.text(query),connection))
# Out:
#             order_id  product_id product_subcategory  total_quantity
# 0     CA-2015-100136        1507           Fasteners           324.0
# 1     CA-2015-100136        1600               Paper           216.0
# 2     CA-2015-100136         122              Labels           143.0
# 3     CA-2015-100136         920         Accessories           130.0
# 4     CA-2015-100136        1216           Fasteners            94.0
# ...              ...         ...                 ...             ...
# 9992  CA-2018-145884         312              Tables             1.0
# 9993  CA-2017-139157         425              Tables             1.0
# 9994  CA-2017-145982        1387              Tables             1.0
# 9995  CA-2015-105165        1356              Tables             1.0
# 9996  CA-2018-151225         428              Tables             1.0
#
# [9997 rows x 4 columns]

# %% [markdown]
# 21. Show the product_id(s), the sum of quantities, where the total sum of its product quantities is greater than or equal to 100.

# %%
query= """
SELECT product_id, SUM(quantity) AS total_quantity
FROM order_details
WHERE quantity >= 100
GROUP BY product_id
ORDER BY product_id;
"""

display(pd.read_sql(sa.text(query),connection))
# Out:
#    product_id  total_quantity
# 0         122           143.0
# 1         920           130.0
# 2        1507           324.0
# 3        1600           216.0

# %% [markdown]
# 22. Bonus question:
# Join all database tables into one dataset that includes all unique columns and download it as a .csv file.

# %%
query= """
SELECT *
FROM orders o
JOIN order_details od ON o.order_id = od.order_id
JOIN customers c ON c.customer_id = o.customer_id
JOIN product p ON p.product_id = od.product_id
"""

df = pd.read_sql_query(query, engine)
filename = "unicorn_data.csv"
df.to_csv(filename, index=False)
